# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Term set

# %% [markdown]
# <image src="1.png">

# %% [markdown]
# Universe in range de $[a\quad c]$

# %%
def triangular_mf(x,a,b,c):
    # a inicio del triangulo
    #b el pico 
    # c el final del triangulo
    y= np.maximum(0, np.minimum((x-a)/(b-a),(c-x)/(c-b)))
    return y

# %%
x=np.linspace(0,10, 500)

# %%
mf1=triangular_mf(x,1,3,5)
mf2 = triangular_mf(x, 4, 6, 8)
mf3 = triangular_mf(x, 7, 9, 10)

# %%
plt.figure(figsize=(10,6))
plt.plot(x, mf1, label='Triangular (1, 3, 5)', linewidth=2)
plt.plot(x, mf2, label='Triangular (4, 6, 8)', linewidth=2)
plt.plot(x, mf3, label='Triangular (7, 9, 10)', linewidth=2)

# %%
x=np.linspace(0,10, 500)

# %%
plt.figure(figsize=(10,6))

plt.plot(x, mf1, label='Triangular (1, 3, 5)', linewidth=2)
plt.plot(x, mf2, label='Triangular (4, 6, 8)', linewidth=2)
plt.plot(x, mf3, label='Triangular (7, 9, 10)', linewidth=2)

example_points= [4.3]

for point in example_points:
    y_values=[
        triangular_mf(point, 1, 3, 5),
        triangular_mf(point, 4, 6, 8),
        triangular_mf(point, 7, 9, 10) 
    ]
    print(y_values)
    for i, y in enumerate(y_values):
        plt.plot([point,point], [0,y], 'k--', alpha=0.7)
        # plt.plot([0,y], [point,point],'b--', alpha=0.7)
        plt.text(point, y, f'{y:.2f}', ha='left', va='bottom', fontsize=10)

plt.title('Term Temperature', fontsize=14)
plt.xlabel('Universo de Discurso', fontsize=12)
plt.ylabel('Grado de Membresía', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()
# Out:
# [np.float64(0.3500000000000001), np.float64(0.1499999999999999), np.float64(0.0)]

# %%
plt.figure(figsize=(10,6))

plt.plot(x, mf1, label='Triangular (1, 3, 5)', linewidth=2)
plt.plot(x, mf2, label='Triangular (4, 6, 8)', linewidth=2)
plt.plot(x, mf3, label='Triangular (7, 9, 10)', linewidth=2)

example_points= [3.7]

for point in example_points:
    y_values=[
        triangular_mf(point, 1, 3, 5),
        triangular_mf(point, 4, 6, 8),
        triangular_mf(point, 7, 9, 10) 
    ]
    print(y_values)
    for i, y in enumerate(y_values):
        plt.plot([point,point], [0,y], 'k--', alpha=0.7)
        # plt.plot([0,y], [point,point],'b--', alpha=0.7)
        plt.text(point, y, f'{y:.2f}', ha='left', va='bottom', fontsize=10)

plt.title('Termset humidity', fontsize=14)
plt.xlabel('Universo de Discurso', fontsize=12)
plt.ylabel('Grado de Membresía', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()
# Out:
# [np.float64(0.6499999999999999), np.float64(0.0), np.float64(0.0)]

# %% [markdown]
# ### Output

# %%
plt.figure(figsize=(10,6))

plt.plot(x, mf1, label='Triangular (1, 3, 5)', linewidth=2)
plt.plot(x, mf2, label='Triangular (4, 6, 8)', linewidth=2)
plt.plot(x, mf3, label='Triangular (7, 9, 10)', linewidth=2)

example_points= [4.6]

for point in example_points:
    y_values=[
        triangular_mf(point, 1, 3, 5),
        triangular_mf(point, 4, 6, 8),
        triangular_mf(point, 7, 9, 10) 
    ]
    print(y_values)
    for i, y in enumerate(y_values):
        plt.plot([point,point], [0,y], 'k--', alpha=0.7)
        # plt.plot([0,y], [point,point],'b--', alpha=0.7)
        plt.text(point, y, f'{y:.2f}', ha='left', va='bottom', fontsize=10)

plt.title('Output  Velocidad', fontsize=14)
plt.xlabel('Universo de Discurso', fontsize=12)
plt.ylabel('Grado de Membresía', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()
# Out:
# [np.float64(0.20000000000000018), np.float64(0.2999999999999998), np.float64(0.0)]

# %% [markdown]
# ### Investigar sistema de inferencia de tipo Mamdani
